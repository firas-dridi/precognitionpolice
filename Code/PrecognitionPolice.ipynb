# %% [markdown]
# <img src="he-arc.png" sytle="position:absolute;top:0px;right:0px;background-color:#363738;" width=400px>
# <h1 style="background-color:#2c3643;color:white;padding:10px;text-align:center;font-size:60px;border-bottom:10px solid white;">
# Precognition Police<br><br>
# <img src="https://media0.giphy.com/media/pcKoz7f46DSa0B569s/giphy.gif?cid=ecf05e47gyrxbqea86o53p998pzp08th57c5hjrsdqetxkig&rid=giphy.gif&ct=g" width=600>
# </h1>

# %% [markdown]
# <div style="background-color:#2F3646;padding:10px;color:#e6e9f0;border-left:10px solid #b3b5b5;">
# <b>ÉLÈVES</b>
#
# Ce projet a été conçu et développé par **Firas Dridi** et **Altin Hajda**, élèves de 2ème année à la HE-ARC en ingénierie des données.
#
# </div>

# %% [markdown]
# ###
#
# <h3 style="padding:10px;border-left:6px solid #2c3643;">
#
# Nettoyage du fichier CSV
#
# </h3>

# %%
import pandas as pd

filepath = "Arrest_Data_from_2010_to_2019.csv"
df_arrests = pd.read_csv(filepath)

df_arrests.head()
# Out:
#    Report ID Report Type Arrest Date    Time  Area ID  Area Name  \
# 0    2377805     BOOKING  06/22/2010  1845.0       16   Foothill
# 1  121920046         RFC  09/28/2012   930.0       19    Mission
# 2  101820989         RFC  10/20/2010   700.0       18  Southeast
# 3   90712341         RFC  03/10/2011   940.0        7   Wilshire
# 4  121909585         RFC  04/01/2012  1715.0       19    Mission
#
#    Reporting District  Age Sex Code Descent Code  ...  \
# 0                1664   46        F            W  ...
# 1                1998   60        M            H  ...
# 2                1829   14        M            H  ...
# 3                 776   45        M            B  ...
# 4                1993   37        M            H  ...
#
#        Disposition Description                                  Address  \
# 0  MISDEMEANOR COMPLAINT FILED                                PENDLETON
# 1  MISDEMEANOR COMPLAINT FILED  7600    WOODMAN                      AV
# ...
